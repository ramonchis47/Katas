# %% [markdown]
# # Ejersicio 1

# %%
primerPlaneta = 149597870
segundoPlaneta = 778547200

distancia = segundoPlaneta - primerPlaneta
print("Las distancias: " , distancia)
distanciaMi = distancia * 0.621
print("La distancia en Millas:" , distanciaMi)

# %% [markdown]
# # Ejercisio 2

# %%
primerPlaneta = int(input("Distancia del primer planeta: "))
segundoPlaneta = int(input("Distancia del segundo planeta: "))
distancia = segundoPlaneta - primerPlaneta
print("Las distancias: " , distancia)
distanciaMi = distancia * 0.621
print("La distancia en Millas:" , abs(distanciaMi))
